# %%
import pandas as pd
import numpy as np
df = pd.read_csv('recipes_normalized.csv')
display(df)
np.set_printoptions(threshold=np.inf)
all_ingredients = unique_ingredients = (
    df['NER']
    .str.split(',')
    .explode()
    .str.strip()
    .str.lower()
    .dropna()
    .unique()
)



len(all_ingredients)
# Out:
#                                        title  \
# 0                        No-Bake Nut Cookies
# 1                      Jewell Ball'S Chicken
# 2                                Creamy Corn
# 3                              Chicken Funny
# 4                       Reeses Cups(Candy)
# ...                                      ...
# 8409  Cheesecake Factory Key Lime Cheesecake
# 8410           Quick And Easy Rice Jambalaya
# 8411                         Ruth'S Dressing
# 8412                            Irish Kisses
# 8413                  Savory Upside-Down Pie
#
#                                             ingredients  \
# 0     200g brown sugar | 120ml evaporated milk | 0.5...
# 1     1 jar chipped beef, cut up | 4 boned chicken b...
# 2     2 pkg. corn | 1 pkg. cream cheese | 67g butter...
# 3     1 chicken | 2 cans chicken gravy | 1 can cream...
# 4     200g peanut butter | 150g graham cracker crumb...
# ...                                                 ...
# 8409  350g graham cracker crumbs | 5.0 tbsp butter, ...
# 8410  1.0 tbsp oil | 1 onion | 120ml celery | 1 clov...
# 8411  50g sugar | 120ml mayonnaise | 60ml milk | 2.0...
# 8412  200g sugar | 100g butter | 120ml milk | 1.0 ts...
# 8413  210g pkg. puff pastry | 680g beef | 1.0 tsp sa...
#
#                                              directions  \
# 0     In a heavy 2-quart saucepan, mix brown sugar, ...
# 1     Place chipped beef on bottom of baking dish. |...
# 2     In a slow cooker, combine all ingredients. Cov...
# 3     Boil and debone chicken. | Put bite size piece...
# 4     Combine first four ingredients and press in 13...
# ...                                                 ...
# 8409  Preheat oven to 350°. | Stir to coat well the ...
# 8410  Heat oil in a large skillet on medium-high hea...
# 8411  Mix all ingredients together. | Shake well. | ...
# 8412  Beat up the butter and all the other ingredien...
# 8413  Thaw pastry. | Mix ground beef, salt, pepper a...
#
#                                                  link    source  \
# 0      www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1     www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2      www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3     www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4     www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# ...                                               ...       ...
# 8409   www.cookbooks.com/Recipe-Details.aspx?id=91702  Gathered
# 8410   www.cookbooks.com/Recipe-Details.aspx?id=98300  Gathered
# 8411  www.cookbooks.com/Recipe-Details.aspx?id=886369  Gathered
# 8412  www.cookbooks.com/Recipe-Details.aspx?id=360047  Gathered
# 8413  www.cookbooks.com/Recipe-Details.aspx?id=612301  Gathered
#
#                                                     NER  avg_rating  \
# 0     ["brown sugar", "milk", "vanilla", "nuts", "bu...         3.3
# 1     ["beef", "chicken breasts", "cream of mushroom...         3.1
# 2     ["frozen corn", "cream cheese", "butter", "gar...         3.4
# 3     ["chicken", "chicken gravy", "cream of mushroo...         3.3
# 4     ["peanut butter", "graham cracker crumbs", "bu...         3.2
# ...                                                 ...         ...
# 8409       ["graham cracker crumbs", "butter", "sugar"]         3.4
# 8410  ["oil", "onion", "celery", "clove garlic", "an...         3.1
# 8411  ["sugar", "mayonnaise", "milk", "red wine vine...         3.9
# 8412  ["sugar", "butter", "milk", "cream of tartar",...         3.5
# 8413  ["frozen puff pastry", "ground beef", "salt", ...         3.0
#
#       n_ratings                                          NER_clean
# 0           149  bite size rice biscuits, brown sugar, butter, ...
# 1           169  beef, chicken breasts, cream of mushroom soup,...
# 2           117  butter, corn, cream cheese, garlic powder, pep...
# 3           351  cheese, chicken, chicken gravy, cream of mushr...
# 4           254  butter, chocolate chips, graham cracker crumbs...
# ...         ...                                                ...
# 8409        192               butter, graham cracker crumbs, sugar
# 8410        475  andouille, cajun-style stewed, celery, chicken...
# 8411        261          mayonnaise, milk, red wine vinegar, sugar
# 8412        207  baking soda, butter, cream of tartar, egg, flo...
# 8413        272  bacon slices, beef, cheese, chervil, egg yolks...
#
# [8414 rows x 9 columns]
# 5587

# %%
import pandas as pd
import numpy as np
import re
import random
from collections import defaultdict, Counter

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)


UNIT_RE = re.compile(
    r'^([\d\.\/]+)\s*'
    r'(g|kg|ml|l|tsp|tbsp|cup|oz|lb|pkg\.?|can|jar|box|clove|slice|piece|pinch|dash|stick)\b',
    re.I
)


CATEGORIES = {
    "protein_meat":   ["beef","chicken","pork","turkey","lamb","steak","bacon","sausage","ham"],
    "protein_fish":   ["salmon","tuna","shrimp","cod","tilapia","crab","fish"],
    "protein_veggie": ["tofu","lentil","chickpea","black bean","kidney bean","bean"],
    "dairy":          ["milk","butter","cheese","cream","yogurt","sour cream","cream cheese"],
    "egg":            ["egg"],
    "produce_veg":    ["onion","garlic","tomato","pepper","carrot","celery","broccoli",
                       "potato","mushroom","corn","spinach","lettuce","zucchini"],
    "produce_fruit":  ["apple","banana","lemon","lime","berry","strawberr","pineapple","orange","peach"],
    "grains":         ["flour","rice","pasta","bread","oat","cracker","noodle","tortilla","cereal"],
    "baking":         ["sugar","brown sugar","baking soda","baking powder","vanilla",
                       "chocolate chip","cocoa","honey","cornstarch"],
    "pantry_staple":  ["oil","vinegar","salt","pepper","soy sauce","ketchup","mustard",
                       "mayonnaise","broth","stock","tomato sauce","worcestershire"],
    "spice_herb":     ["cumin","paprika","oregano","basil","thyme","cinnamon","ginger",
                       "garlic powder","onion powder","parsley","chili","cayenne"],
    "nuts_seeds":     ["almond","walnut","pecan","cashew","peanut","sesame"],
    "canned_goods":   ["canned","condensed","cream of mushroom","cream of chicken"],
    "frozen":         ["frozen"],
}

def get_category(ing: str) -> str:
    for cat, keywords in CATEGORIES.items():
        if any(kw in ing for kw in keywords):
            return cat
    return "other"


ARCHETYPES = {
    "home_baker":       {"baking":0.9,"dairy":0.85,"egg":0.9,"grains":0.8,
                         "pantry_staple":0.7,"nuts_seeds":0.6,"spice_herb":0.5,
                         "produce_veg":0.5,"protein_meat":0.3,"other":0.3},
    "meat_lover":       {"protein_meat":0.95,"pantry_staple":0.85,"spice_herb":0.8,
                         "dairy":0.65,"grains":0.6,"produce_veg":0.6,"egg":0.5,
                         "canned_goods":0.5,"other":0.35},
    "vegetarian":       {"produce_veg":0.95,"produce_fruit":0.8,"protein_veggie":0.85,
                         "grains":0.85,"dairy":0.75,"spice_herb":0.8,"egg":0.7,
                         "pantry_staple":0.75,"baking":0.5,"other":0.3},
    "budget_cook":      {"grains":0.9,"canned_goods":0.85,"pantry_staple":0.8,
                         "protein_meat":0.7,"produce_veg":0.65,"dairy":0.6,
                         "egg":0.7,"baking":0.4,"other":0.25},
    "health_conscious": {"produce_veg":0.95,"produce_fruit":0.9,"protein_fish":0.7,
                         "nuts_seeds":0.8,"grains":0.75,"protein_veggie":0.8,
                         "dairy":0.5,"spice_herb":0.75,"pantry_staple":0.6,"other":0.3},
    "family_cook":      {"protein_meat":0.9,"dairy":0.9,"grains":0.9,"produce_veg":0.85,
                         "pantry_staple":0.85,"canned_goods":0.8,"frozen":0.75,
                         "egg":0.85,"baking":0.65,"spice_herb":0.7,"other":0.4},
    "casual_cook":      {"pantry_staple":0.7,"dairy":0.65,"egg":0.6,"produce_veg":0.55,
                         "grains":0.5,"protein_meat":0.45,"canned_goods":0.5,"other":0.2},
}
ARCHETYPE_WEIGHTS = np.array([0.12, 0.15, 0.13, 0.18, 0.14, 0.16, 0.12])
ARCHETYPE_WEIGHTS /= ARCHETYPE_WEIGHTS.sum()



def parse_amount(s: str):
    try:
        if '/' in s:
            n, d = s.split('/')
            return float(n) / float(d)
        return float(s)
    except:
        return None


def extract_units_from_recipes(recipes_path: str, known_ings: set) -> dict:
    recipes = pd.read_csv(recipes_path, usecols=["ingredients", "NER"])
    ing_data: dict = defaultdict(lambda: defaultdict(list))

    for _, row in recipes.iterrows():
        ner_raw = re.sub(r"[\[\]'\"]", "", str(row["NER"]))
        ner_ings = [x.strip().lower() for x in ner_raw.split(",") if x.strip()]
        lines = [x.strip() for x in str(row["ingredients"]).split("|")]

        for ing in ner_ings:
            if ing not in known_ings:
                continue
            for line in lines:
                if ing in line.lower():
                    m = UNIT_RE.match(line.strip())
                    if m:
                        amt = parse_amount(m.group(1))
                        unit = m.group(2).lower().rstrip('.')
                        if amt and 0 < amt < 5000:
                            ing_data[ing][unit].append(amt)
                    break

    result = {}
    for ing, unit_dict in ing_data.items():
        best_unit = max(unit_dict, key=lambda u: len(unit_dict[u]))
        median_amt = float(np.median(unit_dict[best_unit]))
        result[ing] = (median_amt, best_unit)

    return result


def make_pantry_amount(median_amt: float, unit: str) -> str:
    multiplier = random.uniform(2, 5)
    amt = median_amt * multiplier

    if unit in ("tsp", "tbsp", "pinch", "dash", "clove"):
        amt = round(amt, 1)
    elif unit in ("g", "ml"):
        amt = max(50, round(amt / 50) * 50)
    elif unit in ("can", "pkg", "box", "jar", "piece", "slice", "stick"):
        amt = max(1, round(amt))
    else:
        amt = round(amt, 1)

    return f"{amt} {unit}"




def add_pantry_column(
    ingredients_path: str,
    recipes_path: str,
    n_users: int = 1000,
    top_n: int = 200,
) -> pd.DataFrame:
   


    with open(ingredients_path) as f:
        known_ings = {l.strip().lower() for l in f if l.strip()}
   

    
    
    unit_map = extract_units_from_recipes(recipes_path, known_ings)
    

   
    freq = Counter({ing: len([]) for ing in unit_map})  
   
    recipes_tmp = pd.read_csv(recipes_path, usecols=["NER"])
    for ner_raw in recipes_tmp["NER"]:
        clean = re.sub(r"[\[\]'\"]", "", str(ner_raw))
        for ing in [x.strip().lower() for x in clean.split(",") if x.strip()]:
            if ing in known_ings:
                freq[ing] += 1

    candidates = [ing for ing, _ in freq.most_common(top_n)]
    

    
    cat_map = {ing: get_category(ing) for ing in candidates}

    
    archetype_names = list(ARCHETYPES.keys())
    rows = []

    for uid in range(1, n_users + 1):
        arch_name = np.random.choice(archetype_names, p=ARCHETYPE_WEIGHTS)
        arch = ARCHETYPES[arch_name]

        pantry = {}
        for ing in candidates:
            cat = cat_map[ing]
            prob = arch.get(cat, arch.get("other", 0.3))
            if random.random() < prob:
                if ing in unit_map:
                    median_amt, unit = unit_map[ing]
                    pantry[ing] = make_pantry_amount(median_amt, unit)
                else:
                    pantry[ing] = "1 pkg"

        rows.append({
            "user_id":   uid,
            "archetype": arch_name,
            "pantry":    pantry,
        })

    df = pd.DataFrame(rows).set_index("user_id")
    return df



if __name__ == "__main__":
    df = add_pantry_column(
        ingredients_path="output.txt",
        recipes_path="recipes_normalized.csv",
        n_users=1000,
        top_n=200,
    )

   

    df.to_csv("user_pantries.csv")

# %%
pantries = pd.read_csv('user_pantries.csv')

pantries = pantries.drop(columns=["archetype"])
display(pantries)
# Out:
#      user_id                                             pantry
# 0          1  {'salt': '1.0 tsp', 'sugar': '550 g', 'flour':...
# 1          2  {'flour': '950 g', 'butter': '450 g', 'pepper'...
# 2          3  {'sugar': '900 g', 'flour': '1300 g', 'butter'...
# 3          4  {'salt': '1.1 tsp', 'flour': '1100 g', 'eggs':...
# 4          5  {'salt': '1.1 tsp', 'flour': '800 g', 'butter'...
# ..       ...                                                ...
# 995      996  {'sugar': '950 g', 'flour': '1100 g', 'butter'...
# 996      997  {'salt': '1.6 tsp', 'butter': '450 g', 'eggs':...
# 997      998  {'salt': '1.4 tsp', 'flour': '1800 g', 'butter...
# 998      999  {'salt': '1.8 tsp', 'butter': '300 g', 'eggs':...
# 999     1000  {'salt': '1.6 tsp', 'sugar': '500 g', 'flour':...
#
# [1000 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
import re
import ast
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ── Load data ─────────────────────────────────────────────────────────────────
df = pd.read_csv('recipes_normalized.csv')
df = df.dropna(subset=['NER_clean', 'ingredients']).reset_index(drop=True)

# ── Load users from user_pantries.csv ────────────────────────────────────────
users_df = pd.read_csv('user_pantries.csv')

def parse_pantry(pantry_str):
    pantry = ast.literal_eval(pantry_str)
    fridge = {}
    for ing, amt_str in pantry.items():
        parts = amt_str.strip().split(' ', 1)
        try:
            qty = float(parts[0])
            unit = parts[1] if len(parts) > 1 else 'g'
        except ValueError:
            qty, unit = 1.0, 'pkg'
        fridge[ing] = (qty, unit)
    return fridge

users = [
    {
        'user_id':   row['user_id'],
        'archetype': row['archetype'],
        'fridge':    parse_pantry(row['pantry']),
    }
    for _, row in users_df.iterrows()
]

# ── Build recipe index ────────────────────────────────────────────────────────
df['ner_set'] = df['NER_clean'].apply(
    lambda x: set(i.strip() for i in x.split(',') if i.strip())
)

# ── Parse ingredient quantities from recipes ──────────────────────────────────
qty_pattern = re.compile(r'([\d\.]+)\s*(g|ml|tsp|tbsp|kg|l)\b', re.IGNORECASE)

def parse_quantities(ingredients_str):
    result = {}
    if pd.isna(ingredients_str):
        return result
    for line in ingredients_str.split('|'):
        line = line.strip()
        m = qty_pattern.match(line)
        if m:
            qty  = float(m.group(1))
            unit = m.group(2).lower()
            name = line[m.end():].strip().lower()
            name = re.sub(r'\s+', ' ', name).strip()
            if name:
                result[name] = (qty, unit)
    return result

df['qty_dict'] = df['ingredients'].apply(parse_quantities)

# ── TF-IDF matrix ─────────────────────────────────────────────────────────────
tfidf = TfidfVectorizer(
    tokenizer=lambda x: [i.strip() for i in x.split(',')],
    lowercase=True
)
tfidf_matrix = tfidf.fit_transform(df['NER_clean'])

# ── Unit normalisation ────────────────────────────────────────────────────────
def to_base_unit(qty, unit):
    conversions = {
        'g': 1, 'kg': 1000,
        'ml': 1, 'l': 1000,
        'tsp': 5, 'tbsp': 15,
    }
    base_type = 'g' if unit in ('g', 'kg') else 'ml'
    return qty * conversions.get(unit, 1), base_type

# ── Quantity coverage ─────────────────────────────────────────────────────────
def quantity_coverage(fridge, recipe_qty_dict):
    if not recipe_qty_dict:
        return 1.0
    covered = 0
    for ing, (need_qty, need_unit) in recipe_qty_dict.items():
        match = None
        for fridge_ing, (have_qty, have_unit) in fridge.items():
            if fridge_ing in ing or ing in fridge_ing:
                match = (have_qty, have_unit)
                break
        if match is None:
            continue
        need_base, need_u = to_base_unit(need_qty, need_unit)
        have_base, have_u = to_base_unit(*match)
        if need_u == have_u:
            if have_base >= need_base:
                covered += 1
        else:
            covered += 1  # different unit types, give benefit of the doubt
    return covered / len(recipe_qty_dict)

# ── Recommender ───────────────────────────────────────────────────────────────
def recommend(user, df, tfidf_matrix, tfidf, top_n=10, rating_weight=0.1):
    """
    Scores recipes by:
      - TF-IDF cosine ingredient overlap  60%
      - Quantity coverage                 30%
      - Normalised avg rating             10%
    """
    fridge     = user['fridge']
    fridge_ings = set(fridge.keys())

    # 1. Ingredient overlap
    fridge_str  = ', '.join(fridge_ings)
    user_vec    = tfidf.transform([fridge_str])
    cosine_scores = cosine_similarity(user_vec, tfidf_matrix).flatten()

    # 2. Quantity coverage
    qty_scores = np.array([
        quantity_coverage(fridge, row['qty_dict'])
        for _, row in df.iterrows()
    ])

    # 3. Normalised rating (1-5 → 0-1)
    rating_scores = (df['avg_rating'].fillna(3.0) - 1) / 4

    # 4. Combined score
    final_scores = (
        cosine_scores * 0.60 +
        qty_scores    * 0.30 +
        rating_scores * rating_weight
    )

    top_idx = np.argsort(final_scores)[::-1][:top_n]

    results = df.iloc[top_idx][['title', 'avg_rating']].copy()
    results['score']            = final_scores[top_idx].round(3)
    results['ingredient_match'] = cosine_scores[top_idx].round(3)
    results['qty_coverage']     = qty_scores[top_idx].round(3)
    results['missing_ings']     = [
        ', '.join(df.iloc[i]['ner_set'] - fridge_ings)
        for i in top_idx
    ]
    return results

# ── Preview ───────────────────────────────────────────────────────────────────
user = users[1]
print(f"=== Pantry user {user['user_id']} ({user['archetype']}) ===")
for ing, (qty, unit) in user['fridge'].items():
    print(f"  {qty}{unit}  {ing}")

print("\n=== Top 10 recommendations ===")
recs = recommend(user, df, tfidf_matrix, tfidf, top_n=10)
print(recs.to_string(index=False))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# === Pantry user 2 (casual_cook) ===
#   950.0g  flour
#   450.0g  butter
#   0.9tsp  pepper
#   1700.0ml  egg
#   1000.0ml  sour cream
#   5.0can  tomatoes
#   1.0pkg  onions
#   800.0ml  mayonnaise
#   300.0g  green pepper
#   1000.0ml  chicken
#   350.0ml  shortening
#   3.9tsp  worcestershire sauce
#   1.0pkg  carrots
#   1.0pkg  mushrooms
#   2.4tsp  nutmeg
#   750.0g  bacon
#   450.0ml  vegetable oil
#   4.0can  tomato sauce
#   2.4tsp  paprika
#   1.0pkg  boiling water
#   4.0clove  clove garlic
#   5.9tbsp  soy sauce
#   3.0can  cream of chicken soup
#   4.8tbsp  olive oil
#   2200.0g  chicken breasts
#   1.0pkg  chicken broth
#   250.0g  peanut butter
#   1.6tsp  garlic powder
#   750.0g  mozzarella cheese
#   400.0ml  egg whites
#   6900.0ml  bread
#   3.0can  condensed milk
#   1.0pkg  catsup
#   1.7tsp  garlic salt
#   1450.0g  hamburger
#   2.6tsp  dry mustard
#   1.0pkg  egg yolks
#   4.0can  beans
#   2350.0ml  cabbage
#   4.9tsp  ginger
#   0.4tsp  red pepper
#   550.0ml  salad oil
#   1050.0ml  whipping cream
#   1.0pkg  grated cheese
#   3.0can  tomato soup
#   4.0can  tomato paste
#   800.0g  swiss cheese
#   1.0pkg  ground cinnamon
#   700.0g  cottage cheese
#   2.7tsp  cream of tartar
#   1.0pkg  green peppers
#   800.0g  oats
#   400.0ml  green onion
#   500.0ml  heavy cream
#   4.0can  pork
#   800.0g  graham cracker crumbs
#   700.0ml  cream
#   2.0can  cream of celery soup
#   1.0pkg  stalks celery
#   500.0ml  white vinegar
#   1650.0g  beef
#   1400.0ml  tomato juice
#   1.7tsp  curry powder
#   1.6tsp  almond extract
#   1.0pkg  mandarin oranges
#   850.0ml  dates
#   1.0pkg  strawberries
#   600.0ml  cauliflower
#   950.0ml  shell
#   800.0g  american cheese
#   450.0ml  cider vinegar
#   1.0pkg  frozen strawberries
#   500.0ml  flaked coconut
#   4.0can  mushroom soup
#   1.0pkg  whole kernel corn
#   4.0can  condensed cream
#   4.0pkg  flour tortillas
#   2.5tsp  tabasco sauce
#   1450.0g  cake flour
#   750.0ml  whipped cream
#   1.0pkg  ground nutmeg
#
# === Top 10 recommendations ===
#                             title  avg_rating  score  ingredient_match  qty_coverage                  missing_ings
#                    Sour Cream Dip         3.8  0.508             0.231           1.0
#           Easy Oven-Fried Chicken         3.5  0.481             0.198           1.0                          salt
#          Ham And Cheese Americana         3.4  0.481             0.202           1.0                        olives
#                 Crock-Pot Chicken         2.7  0.481             0.231           1.0                          salt
#    Tortilla Roll-Ups(Appetizer)           3.3  0.479             0.202           1.0                  cream cheese
#    Bacon-Flavored Chicken Breasts         3.8  0.478             0.180           1.0        cream of mushroom soup
#    Chicken And Tortilla Dumplings         3.8  0.477             0.179           1.0  chicken bouillon cubes, salt
#                      Tomato Gravy         4.0  0.477             0.170           1.0 salt, bacon drippings, tomato
# Corned Beef And Cabbage Casserole         3.7  0.476             0.181           1.0            corned beef, onion
#                            Runzas         3.4  0.475             0.192           1.0           salt, onion, garlic
